# %%
import pandas as pd
from IPython.display import display 

data = pd.read_csv('../data/br_sp_gov_ssp_ocorrencias_registradas.csv',sep=',')
display(data)
# Out:
# ['Presidente Prudente' 'Ribeirão Preto' 'Sorocaba' 'Araçatuba'
#  'Grande São Paulo (exclui a Capital)' 'São José do Rio Preto' 'Bauru'
#  'Campinas' 'Piracicaba' 'São José dos Campos' 'Santos' 'Capital']
